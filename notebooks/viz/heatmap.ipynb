# %% [markdown]
# # heatmap demonstration
# - This notebook is part of biokit
#  - https://github.com/biokit/biokit
#  - https://pypi.python.org/pypi/biokit
#
# - heatmap with dendograms: heatmap

# %%
# %pylab inline
from sequana.viz import Heatmap
from sequana.viz.heatmap import get_heatmap_df
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = get_heatmap_df() # this is a simple test example

# %%
h = Heatmap(df)
layout = h.plot()

# %%
import pandas as pd
df = pd.DataFrame(numpy.random.randn(40,40))
df[0] += 5
df[10] +=10
df[20] +=5
df.iloc[5] += 5
df.iloc[15] +=5
df.iloc[25] +=5

h.df = df.copy()
layout = h.plot(cmap="RdGy",vmin=-5, vmax=10)
